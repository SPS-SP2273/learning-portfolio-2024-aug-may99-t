# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Good), Exercises</span></div>

# %% [markdown]
# ## Exercise 1

# %%
while True:
    print('*', end='')

# did interrupt kernel (KeyboardInterrupt error).
# Out:
# **************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************** ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 while True:
# ----> 2     print('*', end='')
#       4 # did interupt kernel.
#
# File /opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py:681, in OutStream.write(self, string)
#     678     msg = "I/O operation on closed file"
#     679     raise ValueError(msg)
# --> 681 is_child = not self._is_master_process()
#     682 # only touch the buffer in the IO thread to avoid races
#     683 with self._buffer_lock:
#
# File /opt/miniconda3/lib/python3.12/site-packages/ipykernel/iostream.py:550, in OutStream._is_master_process(self)
#     547     self.watch_fd_thread.daemon = True
#     548     self.watch_fd_thread.start()
# --> 550 def _is_master_process(self):
#     551     return os.getpid() == self._master_pid
#     553 def set_parent(self, parent):
#
# KeyboardInterrupt:

# %% [markdown]
# ## Exercise 2

# %%
print = 'PRINT'
print('Hello World')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 print = 'PRINT'
# ----> 2 print('Hello World')
#
# TypeError: 'str' object is not callable

# %% [markdown]
# ## Exercise 3

# %%
# %%timeit
squares = [i**2 for i in range(10)]

# This code will be faster as it executes less commands 
#590ns is the average time taken to run the code with a standard deviation of 5.45ns which was derived by running the for loop 7,000,000
# Out:
# 590 ns ± 5.45 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# %%timeit
squares = list()
for i in range(10):
    squares.append(i**2)
# Out:
# 639 ns ± 2.76 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
squares = [i**2 for i in range(10)]
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
squares = list()
for i in range(10):
    squares.append(i**2)

# %% [markdown]
# ## Footnotes
