# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need) Exercises</span></div>

# %% [markdown]
# ## Task 1

# %%
date = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

file_name = 'oct-08_singapore.txt'
month = old_file_name.split('-')[0]
num_month = date[month]
day_city_type = old_file_name.split('-')[1]
day = day_city_type.split('_')[0]
city_type = day_city_type.split('_')[1]
print(f'{num_month}-{day}-{city}')
# Out:
# 10-08-singapore.txt

# %% [markdown]
# ## Task 2

# %%
date = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

def rename_my_file(old_file_name):
    month = old_file_name.split('-')[0]
    num_month = date[month]
    day_city_type = old_file_name.split('-')[1]
    day = day_city_type.split('_')[0]
    city_type = day_city_type.split('_')[1]
    return f'{num_month}-{day}-{city}'
    

rename_my_file('may-22_philippines.txt')
# Out:
# '05-22-philippines.txt'

# %% [markdown]
# ## Task 4

# %%
old_names = ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']

for x in old_names:
    new_name = rename_my_file(x)
    print(f'{x} ----> {new_name}')
# Out:
# oct-08_singapore.txt ----> 10-08-singapore.txt
# jul-10_cairo.txt ----> 07-10-cairo.txt
# may-15_dhaka.txt ----> 05-15-dhaka.txt
# may-13_cairo.txt ----> 05-13-cairo.txt
# oct-21_cairo.txt ----> 10-21-cairo.txt
# jan-10_singapore.txt ----> 01-10-singapore.txt
# jun-20_tokyo.txt ----> 06-20-tokyo.txt
# aug-06_jakarta.txt ----> 08-06-jakarta.txt
# dec-21_karachi.txt ----> 12-21-karachi.txt
# jan-01_tokyo.txt ----> 01-01-tokyo.txt

# %% [markdown]
# ##  Task 4

# %%
import os
import glob
import shutil

old_names = glob.glob('os-colla*/*')
for x in old_names:
    name = rename_my_file(os.path.split(x)[-1])
    name = os.path.join('os-collaboration-exercise-data', name)
    os.rename(x, name)

# %% [markdown]
# ## Task 5

# %%
cities = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

for x in cities:
    to_folder = os.path.join('os-collaboration-exercise-data', x)
    os.mkdir(to_folder)

# %% [markdown]
# ## Task 6

# %%
all_files = glob.glob('os-colla*/*')
cairo_files = []
for x in all_files:
    if 'cairo' in x:
        cairo_files.append(x) #i realise i didn't really need this list
                              #but im too scared ill have to delete all my files again if i run this with shorter code
for x in cairo_files:
    path_to_cairo = os.path.join('os-collaboration-exercise-data', 'Cairo')
    shutil.copy(x, path_to_cairo)
    print(f'Copied file to {path_to_cairo}')
# Out:
# Copied file to os-collaboration-exercise-data\Cairo
# Copied file to os-collaboration-exercise-data\Cairo
# Copied file to os-collaboration-exercise-data\Cairo
# Copied file to os-collaboration-exercise-data\Cairo
# Copied file to os-collaboration-exercise-data\Cairo
# Copied file to os-collaboration-exercise-data\Cairo
# Copied file to os-collaboration-exercise-data\Cairo
# Copied file to os-collaboration-exercise-data\Cairo
# Copied file to os-collaboration-exercise-data\Cairo
# Copied file to os-collaboration-exercise-data\Cairo
# Copied file to os-collaboration-exercise-data\Cairo
# Copied file to os-collaboration-exercise-data\Cairo
# Copied file to os-collaboration-exercise-data\Cairo
# Copied file to os-collaboration-exercise-data\Cairo
# Copied file to os-collaboration-exercise-data\Cairo
# Copied file to os-collaboration-exercise-data\Cairo
# Copied file to os-collaboration-exercise-data\Cairo
# Copied file to os-collaboration-exercise-data\Cairo
# ...

# %% [markdown]
# ## Task 7

# %%
all_files = glob.glob('os-colla*/*')

city_dict = {'cairo': 'Cairo', 'dhaka': 'Dhaka', 'jakarta': 'Jakarta',
             'karachi': 'Karachi', 'manila':'Manila', 'melbourne': 'Melbourne',
             'osaka': 'Osaka', 'shanghai': 'Shanghai', 'singapore': 'Singapore', 
             'tokyo': 'Tokyo'}

for x in all_files:
    for city, folder in city_dict.items():
        if city in x:
            path_to_destination = os.path.join('os-collaboration-exercise-data', folder)
            shutil.copy(x, path_to_destination)
            print(f'Copied {x} to {path_to_destination}')
# Out:
# Copied os-collaboration-exercise-data\01-01-manila.jpg to os-collaboration-exercise-data\Manila
# Copied os-collaboration-exercise-data\01-01-manila.txt to os-collaboration-exercise-data\Manila
# Copied os-collaboration-exercise-data\01-01-osaka.pdf to os-collaboration-exercise-data\Osaka
# Copied os-collaboration-exercise-data\01-01-osaka.txt to os-collaboration-exercise-data\Osaka
# Copied os-collaboration-exercise-data\01-02-cairo.pdf to os-collaboration-exercise-data\Cairo
# Copied os-collaboration-exercise-data\01-02-cairo.txt to os-collaboration-exercise-data\Cairo
# Copied os-collaboration-exercise-data\01-02-karachi.jpg to os-collaboration-exercise-data\Karachi
# Copied os-collaboration-exercise-data\01-02-karachi.txt to os-collaboration-exercise-data\Karachi
# Copied os-collaboration-exercise-data\01-02-manila.png to os-collaboration-exercise-data\Manila
# Copied os-collaboration-exercise-data\01-02-manila.txt to os-collaboration-exercise-data\Manila
# ...
